# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
#2
s = np.pi/2
R=5
p = 2*R*np.cos(s)
plt.polar(p)

# %%
#3
x = np.linspace(0, 5, 100)
y = 3*x
plt.polar(x,y)

# %%
#1
def polar2cart(r,a):
    x = r*np.cos(a)
    y = r*np.sin(a)
    return x,y
polar2cart(50, 180)
# Out:
# (-29.92300345289291, -40.05763178669152)
